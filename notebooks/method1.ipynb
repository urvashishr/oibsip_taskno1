# %% [markdown]
# <a href="https://colab.research.google.com/github/urvashishr/oibsip_taskno1/blob/main/notebooks/method1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
import os

zip_path = "/content/working.zip"   # path to your uploaded zip
extract_folder = "/content/working" # where to extract

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_folder)

print("Extracted files to:", extract_folder)
# Out:
# Extracted files to: /content/working

# %%
# List files inside the extracted folder
for root, dirs, files in os.walk(extract_folder):
    for file in files:
        print(os.path.join(root, file))
# Out:
# /content/working/working/.DS_Store
# /content/working/working/synthdata/.DS_Store
# /content/working/working/synthdata/data.yaml
# /content/working/working/synthdata/images/.DS_Store
# /content/working/working/synthdata/images/val/val_0233.png
# /content/working/working/synthdata/images/val/val_0703.png
# /content/working/working/synthdata/images/val/val_0171.png
# /content/working/working/synthdata/images/val/val_0625.png
# /content/working/working/synthdata/images/val/val_0720.png
# /content/working/working/synthdata/images/val/val_0503.png
# /content/working/working/synthdata/images/val/val_0424.png
# /content/working/working/synthdata/images/val/val_0299.png
# /content/working/working/synthdata/images/val/val_0484.png
# /content/working/working/synthdata/images/val/val_0364.png
# /content/working/working/synthdata/images/val/val_0628.png
# /content/working/working/synthdata/images/val/val_0279.png
# /content/working/working/synthdata/images/val/val_0770.png
# /content/working/working/synthdata/images/val/val_0050.png
# /content/working/working/synthdata/images/val/val_0600.png
# /content/working/working/synthdata/images/val/val_0368.png
# /content/working/working/synthdata/images/val/val_0807.png
# /content/working/working/synthdata/images/val/val_0601.png
# /content/working/working/synthdata/images/val/val_0129.png
# /content/working/working/synthdata/images/val/val_0242.png
# /content/working/working/synthdata/images/val/val_0858.png
# /content/working/working/synthdata/images/val/val_0734.png
# /content/working/working/synthdata/images/val/val_0471.png
# /content/working/working/synthdata/images/val/val_0819.png
# /content/working/working/synthdata/images/val/val_0721.png
# /content/working/working/synthdata/images/val/val_0540.png
# /content/working/working/synthdata/images/val/val_0468.png
# /content/working/working/synthdata/images/val/val_0190.png
# /content/working/working/synthdata/images/val/val_0318.png
# /content/working/working/synthdata/images/val/val_0641.png
# /content/working/working/synthdata/images/val/val_0559.png
# /content/working/working/synthdata/images/val/val_0268.png
# /content/working/working/synthdata/images/val/val_0175.png
# /content/working/working/synthdata/images/val/val_0003.png
# /content/working/working/synthdata/images/val/val_0736.png
# /content/working/working/synthdata/images/val/val_0672.png
# /content/working/working/synthdata/images/val/val_0531.png
# /content/working/working/synthdata/images/val/val_0798.png
# /content/working/working/synthdata/images/val/val_0833.png
# /content/working/working/synthdata/images/val/val_0316.png
# /content/working/working/synthdata/images/val/val_0570.png
# /content/working/working/synthdata/images/val/val_0426.png
# /content/working/working/synthdata/images/val/val_0218.png
# /content/working/working/synthdata/images/val/val_0712.png
# /content/working/working/synthdata/images/val/val_0045.png
# /content/working/working/synthdata/images/val/val_0301.png
# /content/working/working/synthdata/images/val/val_0438.png
# /content/working/working/synthdata/images/val/val_0634.png
# /content/working/working/synthdata/images/val/val_0379.png
# /content/working/working/synthdata/images/val/val_0815.png
# /content/working/working/synthdata/images/val/val_0206.png
# /content/working/working/synthdata/images/val/val_0660.png
# /content/working/working/synthdata/images/val/val_0146.png
# /content/working/working/synthdata/images/val/val_0293.png
# /content/working/working/synthdata/images/val/val_0836.png
# /content/working/working/synthdata/images/val/val_0403.png
# /content/working/working/synthdata/images/val/val_0555.png
# /content/working/working/synthdata/images/val/val_0580.png
# /content/working/working/synthdata/images/val/val_0122.png
# /content/working/working/synthdata/images/val/val_0781.png
# /content/working/working/synthdata/images/val/val_0383.png
# /content/working/working/synthdata/images/val/val_0212.png
# /content/working/working/synthdata/images/val/val_0599.png
# /content/working/working/synthdata/images/val/val_0718.png
# /content/working/working/synthdata/images/val/val_0729.png
# /content/working/working/synthdata/images/val/val_0519.png
# /content/working/working/synthdata/images/val/val_0534.png
# /content/working/working/synthdata/images/val/val_0312.png
# /content/working/working/synthdata/images/val/val_0358.png
# /content/working/working/synthdata/images/val/val_0141.png
# /content/working/working/synthdata/images/val/val_0336.png
# /content/working/working/synthdata/images/val/val_0563.png
# /content/working/working/synthdata/images/val/val_0579.png
# /content/working/working/synthdata/images/val/val_0558.png
# /content/working/working/synthdata/images/val/val_0322.png
# /content/working/working/synthdata/images/val/val_0197.png
# /content/working/working/synthdata/images/val/val_0739.png
# /content/working/working/synthdata/images/val/val_0816.png
# /content/working/working/synthdata/images/val/val_0053.png
# /content/working/working/synthdata/images/val/val_0166.png
# /content/working/working/synthdata/images/val/val_0034.png
# /content/working/working/synthdata/images/val/val_0048.png
# /content/working/working/synthdata/images/val/val_0360.png
# /content/working/working/synthdata/images/val/val_0307.png
# /content/working/working/synthdata/images/val/val_0183.png
# /content/working/working/synthdata/images/val/val_0453.png
# /content/working/working/synthdata/images/val/val_0744.png
# /content/working/working/synthdata/images/val/val_0689.png
# /content/working/working/synthdata/images/val/val_0517.png
# /content/working/working/synthdata/images/val/val_0750.png
# /content/working/working/synthdata/images/val/val_0351.png
# /content/working/working/synthdata/images/val/val_0414.png
# /content/working/working/synthdata/images/val/val_0377.png
# /content/working/working/synthdata/images/val/val_0229.png
# /content/working/working/synthdata/images/val/val_0825.png
# /content/working/working/synthdata/images/val/val_0574.png
# /content/working/working/synthdata/images/val/val_0338.png
# /content/working/working/synthdata/images/val/val_0195.png
# /content/working/working/synthdata/images/val/val_0097.png
# /content/working/working/synthdata/images/val/val_0161.png
# /content/working/working/synthdata/images/val/val_0416.png
# /content/working/working/synthdata/images/val/val_0616.png
# /content/working/working/synthdata/images/val/val_0812.png
# /content/working/working/synthdata/images/val/val_0250.png
# /content/working/working/synthdata/images/val/val_0593.png
# /content/working/working/synthdata/images/val/val_0024.png
# /content/working/working/synthdata/images/val/val_0091.png
# /content/working/working/synthdata/images/val/val_0587.png
# /content/working/working/synthdata/images/val/val_0785.png
# /content/working/working/synthdata/images/val/val_0142.png
# /content/working/working/synthdata/images/val/val_0861.png
# /content/working/working/synthdata/images/val/val_0472.png
# /content/working/working/synthdata/images/val/val_0745.png
# /content/working/working/synthdata/images/val/val_0282.png
# /content/working/working/synthdata/images/val/val_0708.png
# /content/working/working/synthdata/images/val/val_0779.png
# /content/working/working/synthdata/images/val/val_0008.png
# /content/working/working/synthdata/images/val/val_0119.png
# /content/working/working/synthdata/images/val/val_0775.png
# /content/working/working/synthdata/images/val/val_0757.png
# /content/working/working/synthdata/images/val/val_0813.png
# /content/working/working/synthdata/images/val/val_0658.png
# /content/working/working/synthdata/images/val/val_0477.png
# /content/working/working/synthdata/images/val/val_0646.png
# /content/working/working/synthdata/images/val/val_0553.png
# /content/working/working/synthdata/images/val/val_0077.png
# /content/working/working/synthdata/images/val/val_0463.png
# /content/working/working/synthdata/images/val/val_0589.png
# /content/working/working/synthdata/images/val/val_0706.png
# /content/working/working/synthdata/images/val/val_0302.png
# /content/working/working/synthdata/images/val/val_0749.png
# /content/working/working/synthdata/images/val/val_0349.png
# /content/working/working/synthdata/images/val/val_0518.png
# /content/working/working/synthdata/images/val/val_0612.png
# /content/working/working/synthdata/images/val/val_0185.png
# /content/working/working/synthdata/images/val/val_0513.png
# /content/working/working/synthdata/images/val/val_0080.png
# /content/working/working/synthdata/images/val/val_0571.png
# /content/working/working/synthdata/images/val/val_0086.png
# /content/working/working/synthdata/images/val/val_0252.png
# /content/working/working/synthdata/images/val/val_0321.png
# /content/working/working/synthdata/images/val/val_0220.png
# /content/working/working/synthdata/images/val/val_0260.png
# /content/working/working/synthdata/images/val/val_0545.png
# /content/working/working/synthdata/images/val/val_0309.png
# /content/working/working/synthdata/images/val/val_0162.png
# /content/working/working/synthdata/images/val/val_0778.png
# /content/working/working/synthdata/images/val/val_0032.png
# /content/working/working/synthdata/images/val/val_0357.png
# /content/working/working/synthdata/images/val/val_0604.png
# /content/working/working/synthdata/images/val/val_0172.png
# /content/working/working/synthdata/images/val/val_0475.png
# /content/working/working/synthdata/images/val/val_0374.png
# /content/working/working/synthdata/images/val/val_0704.png
# /content/working/working/synthdata/images/val/val_0620.png
# /content/working/working/synthdata/images/val/val_0500.png
# /content/working/working/synthdata/images/val/val_0635.png
# /content/working/working/synthdata/images/val/val_0319.png
# /content/working/working/synthdata/images/val/val_0213.png
# /content/working/working/synthdata/images/val/val_0629.png
# /content/working/working/synthdata/images/val/val_0158.png
# /content/working/working/synthdata/images/val/val_0621.png
# /content/working/working/synthdata/images/val/val_0803.png
# /content/working/working/synthdata/images/val/val_0165.png
# /content/working/working/synthdata/images/val/val_0451.png
# /content/working/working/synthdata/images/val/val_0492.png
# /content/working/working/synthdata/images/val/val_0353.png
# /content/working/working/synthdata/images/val/val_0096.png
# /content/working/working/synthdata/images/val/val_0391.png
# /content/working/working/synthdata/images/val/val_0685.png
# /content/working/working/synthdata/images/val/val_0692.png
# /content/working/working/synthdata/images/val/val_0772.png
# /content/working/working/synthdata/images/val/val_0840.png
# /content/working/working/synthdata/images/val/val_0673.png
# /content/working/working/synthdata/images/val/val_0396.png
# /content/working/working/synthdata/images/val/val_0630.png
# /content/working/working/synthdata/images/val/val_0020.png
# /content/working/working/synthdata/images/val/val_0652.png
# /content/working/working/synthdata/images/val/val_0409.png
# /content/working/working/synthdata/images/val/val_0735.png
# /content/working/working/synthdata/images/val/val_0554.png
# /content/working/working/synthdata/images/val/val_0496.png
# /content/working/working/synthdata/images/val/val_0249.png
# /content/working/working/synthdata/images/val/val_0297.png
# /content/working/working/synthdata/images/val/val_0509.png
# /content/working/working/synthdata/images/val/val_0056.png
# /content/working/working/synthdata/images/val/val_0323.png
# /content/working/working/synthdata/images/val/val_0546.png
# /content/working/working/synthdata/images/val/val_0806.png
# /content/working/working/synthdata/images/val/val_0291.png
# /content/working/working/synthdata/images/val/val_0187.png
# /content/working/working/synthdata/images/val/val_0253.png
# /content/working/working/synthdata/images/val/val_0796.png
# /content/working/working/synthdata/images/val/val_0311.png
# /content/working/working/synthdata/images/val/val_0281.png
# /content/working/working/synthdata/images/val/val_0063.png
# /content/working/working/synthdata/images/val/val_0066.png
# /content/working/working/synthdata/images/val/val_0254.png
# /content/working/working/synthdata/images/val/val_0611.png
# /content/working/working/synthdata/images/val/val_0548.png
# /content/working/working/synthdata/images/val/val_0655.png
# /content/working/working/synthdata/images/val/val_0515.png
# /content/working/working/synthdata/images/val/val_0114.png
# /content/working/working/synthdata/images/val/val_0275.png
# /content/working/working/synthdata/images/val/val_0624.png
# /content/working/working/synthdata/images/val/val_0512.png
# /content/working/working/synthdata/images/val/val_0841.png
# /content/working/working/synthdata/images/val/val_0303.png
# /content/working/working/synthdata/images/val/val_0408.png
# /content/working/working/synthdata/images/val/val_0713.png
# /content/working/working/synthdata/images/val/val_0290.png
# /content/working/working/synthdata/images/val/val_0425.png
# /content/working/working/synthdata/images/val/val_0606.png
# /content/working/working/synthdata/images/val/val_0334.png
# /content/working/working/synthdata/images/val/val_0239.png
# /content/working/working/synthdata/images/val/val_0100.png
# /content/working/working/synthdata/images/val/val_0355.png
# /content/working/working/synthdata/images/val/val_0313.png
# /content/working/working/synthdata/images/val/val_0259.png
# /content/working/working/synthdata/images/val/val_0191.png
# /content/working/working/synthdata/images/val/val_0552.png
# /content/working/working/synthdata/images/val/val_0810.png
# /content/working/working/synthdata/images/val/val_0520.png
# /content/working/working/synthdata/images/val/val_0174.png
# /content/working/working/synthdata/images/val/val_0285.png
# /content/working/working/synthdata/images/val/val_0527.png
# /content/working/working/synthdata/images/val/val_0682.png
# /content/working/working/synthdata/images/val/val_0761.png
# /content/working/working/synthdata/images/val/val_0487.png
# /content/working/working/synthdata/images/val/val_0725.png
# /content/working/working/synthdata/images/val/val_0493.png
# /content/working/working/synthdata/images/val/val_0180.png
# /content/working/working/synthdata/images/val/val_0101.png
# /content/working/working/synthdata/images/val/val_0005.png
# /content/working/working/synthdata/images/val/val_0457.png
# /content/working/working/synthdata/images/val/val_0332.png
# /content/working/working/synthdata/images/val/val_0511.png
# /content/working/working/synthdata/images/val/val_0516.png
# /content/working/working/synthdata/images/val/val_0700.png
# /content/working/working/synthdata/images/val/val_0598.png
# /content/working/working/synthdata/images/val/val_0367.png
# /content/working/working/synthdata/images/val/val_0844.png
# /content/working/working/synthdata/images/val/val_0762.png
# /content/working/working/synthdata/images/val/val_0184.png
# /content/working/working/synthdata/images/val/val_0147.png
# /content/working/working/synthdata/images/val/val_0644.png
# /content/working/working/synthdata/images/val/val_0535.png
# /content/working/working/synthdata/images/val/val_0547.png
# /content/working/working/synthdata/images/val/val_0774.png
# /content/working/working/synthdata/images/val/val_0663.png
# /content/working/working/synthdata/images/val/val_0251.png
# /content/working/working/synthdata/images/val/val_0576.png
# /content/working/working/synthdata/images/val/val_0369.png
# /content/working/working/synthdata/images/val/val_0829.png
# /content/working/working/synthdata/images/val/val_0035.png
# /content/working/working/synthdata/images/val/val_0344.png
# /content/working/working/synthdata/images/val/val_0326.png
# /content/working/working/synthdata/images/val/val_0378.png
# /content/working/working/synthdata/images/val/val_0400.png
# /content/working/working/synthdata/images/val/val_0267.png
# /content/working/working/synthdata/images/val/val_0698.png
# /content/working/working/synthdata/images/val/val_0763.png
# /content/working/working/synthdata/images/val/val_0623.png
# /content/working/working/synthdata/images/val/val_0588.png
# /content/working/working/synthdata/images/val/val_0269.png
# /content/working/working/synthdata/images/val/val_0286.png
# /content/working/working/synthdata/images/val/val_0495.png
# /content/working/working/synthdata/images/val/val_0782.png
# /content/working/working/synthdata/images/val/val_0793.png
# /content/working/working/synthdata/images/val/val_0109.png
# /content/working/working/synthdata/images/val/val_0087.png
# /content/working/working/synthdata/images/val/val_0052.png
# /content/working/working/synthdata/images/val/val_0594.png
# /content/working/working/synthdata/images/val/val_0645.png
# /content/working/working/synthdata/images/val/val_0544.png
# /content/working/working/synthdata/images/val/val_0764.png
# /content/working/working/synthdata/images/val/val_0153.png
# /content/working/working/synthdata/images/val/val_0149.png
# /content/working/working/synthdata/images/val/val_0857.png
# /content/working/working/synthdata/images/val/val_0551.png
# /content/working/working/synthdata/images/val/val_0773.png
# /content/working/working/synthdata/images/val/val_0442.png
# /content/working/working/synthdata/images/val/val_0380.png
# /content/working/working/synthdata/images/val/val_0862.png
# /content/working/working/synthdata/images/val/val_0116.png
# /content/working/working/synthdata/images/val/val_0203.png
# /content/working/working/synthdata/images/val/val_0619.png
# /content/working/working/synthdata/images/val/val_0273.png
# /content/working/working/synthdata/images/val/val_0021.png
# /content/working/working/synthdata/images/val/val_0198.png
# /content/working/working/synthdata/images/val/val_0791.png
# /content/working/working/synthdata/images/val/val_0298.png
# /content/working/working/synthdata/images/val/val_0701.png
# /content/working/working/synthdata/images/val/val_0525.png
# /content/working/working/synthdata/images/val/val_0210.png
# /content/working/working/synthdata/images/val/val_0666.png
# /content/working/working/synthdata/images/val/val_0632.png
# /content/working/working/synthdata/images/val/val_0423.png
# /content/working/working/synthdata/images/val/val_0231.png
# /content/working/working/synthdata/images/val/val_0459.png
# /content/working/working/synthdata/images/val/val_0653.png
# /content/working/working/synthdata/images/val/val_0562.png
# /content/working/working/synthdata/images/val/val_0802.png
# /content/working/working/synthdata/images/val/val_0205.png
# /content/working/working/synthdata/images/val/val_0668.png
# /content/working/working/synthdata/images/val/val_0150.png
# /content/working/working/synthdata/images/val/val_0192.png
# /content/working/working/synthdata/images/val/val_0536.png
# /content/working/working/synthdata/images/val/val_0361.png
# /content/working/working/synthdata/images/val/val_0565.png
# /content/working/working/synthdata/images/val/val_0746.png
# /content/working/working/synthdata/images/val/val_0695.png
# /content/working/working/synthdata/images/val/val_0288.png
# /content/working/working/synthdata/images/val/val_0155.png
# /content/working/working/synthdata/images/val/val_0751.png
# /content/working/working/synthdata/images/val/val_0780.png
# /content/working/working/synthdata/images/val/val_0390.png
# /content/working/working/synthdata/images/val/val_0381.png
# /content/working/working/synthdata/images/val/val_0018.png
# /content/working/working/synthdata/images/val/val_0133.png
# /content/working/working/synthdata/images/val/val_0015.png
# /content/working/working/synthdata/images/val/val_0217.png
# /content/working/working/synthdata/images/val/val_0178.png
# /content/working/working/synthdata/images/val/val_0709.png
# /content/working/working/synthdata/images/val/val_0295.png
# /content/working/working/synthdata/images/val/val_0240.png
# /content/working/working/synthdata/images/val/val_0199.png
# /content/working/working/synthdata/images/val/val_0030.png
# /content/working/working/synthdata/images/val/val_0483.png
# /content/working/working/synthdata/images/val/val_0850.png
# /content/working/working/synthdata/images/val/val_0177.png
# /content/working/working/synthdata/images/val/val_0117.png
# /content/working/working/synthdata/images/val/val_0042.png
# /content/working/working/synthdata/images/val/val_0314.png
# /content/working/working/synthdata/images/val/val_0363.png
# /content/working/working/synthdata/images/val/val_0783.png
# /content/working/working/synthdata/images/val/val_0647.png
# /content/working/working/synthdata/images/val/val_0134.png
# /content/working/working/synthdata/images/val/val_0209.png
# /content/working/working/synthdata/images/val/val_0346.png
# /content/working/working/synthdata/images/val/val_0667.png
# /content/working/working/synthdata/images/val/val_0412.png
# /content/working/working/synthdata/images/val/val_0469.png
# /content/working/working/synthdata/images/val/val_0272.png
# /content/working/working/synthdata/images/val/val_0226.png
# /content/working/working/synthdata/images/val/val_0659.png
# /content/working/working/synthdata/images/val/val_0699.png
# /content/working/working/synthdata/images/val/val_0454.png
# /content/working/working/synthdata/images/val/val_0567.png
# /content/working/working/synthdata/images/val/val_0450.png
# /content/working/working/synthdata/images/val/val_0055.png
# /content/working/working/synthdata/images/val/val_0622.png
# /content/working/working/synthdata/images/val/val_0478.png
# /content/working/working/synthdata/images/val/val_0441.png
# /content/working/working/synthdata/images/val/val_0228.png
# /content/working/working/synthdata/images/val/val_0482.png
# /content/working/working/synthdata/images/val/val_0225.png
# /content/working/working/synthdata/images/val/val_0115.png
# /content/working/working/synthdata/images/val/val_0760.png
# /content/working/working/synthdata/images/val/val_0028.png
# /content/working/working/synthdata/images/val/val_0446.png
# /content/working/working/synthdata/images/val/val_0016.png
# /content/working/working/synthdata/images/val/val_0207.png
# /content/working/working/synthdata/images/val/val_0636.png
# /content/working/working/synthdata/images/val/val_0494.png
# /content/working/working/synthdata/images/val/val_0665.png
# /content/working/working/synthdata/images/val/val_0046.png
# /content/working/working/synthdata/images/val/val_0786.png
# /content/working/working/synthdata/images/val/val_0071.png
# /content/working/working/synthdata/images/val/val_0561.png
# /content/working/working/synthdata/images/val/val_0188.png
# /content/working/working/synthdata/images/val/val_0256.png
# /content/working/working/synthdata/images/val/val_0591.png
# /content/working/working/synthdata/images/val/val_0202.png
# /content/working/working/synthdata/images/val/val_0662.png
# /content/working/working/synthdata/images/val/val_0083.png
# /content/working/working/synthdata/images/val/val_0696.png
# /content/working/working/synthdata/images/val/val_0300.png
# /content/working/working/synthdata/images/val/val_0395.png
# /content/working/working/synthdata/images/val/val_0255.png
# /content/working/working/synthdata/images/val/val_0308.png
# /content/working/working/synthdata/images/val/val_0727.png
# /content/working/working/synthdata/images/val/val_0072.png
# /content/working/working/synthdata/images/val/val_0865.png
# /content/working/working/synthdata/images/val/val_0248.png
# /content/working/working/synthdata/images/val/val_0722.png
# /content/working/working/synthdata/images/val/val_0352.png
# /content/working/working/synthdata/images/val/val_0602.png
# /content/working/working/synthdata/images/val/val_0054.png
# /content/working/working/synthdata/images/val/val_0004.png
# /content/working/working/synthdata/images/val/val_0335.png
# /content/working/working/synthdata/images/val/val_0476.png
# /content/working/working/synthdata/images/val/val_0138.png
# /content/working/working/synthdata/images/val/val_0118.png
# /content/working/working/synthdata/images/val/val_0742.png
# /content/working/working/synthdata/images/val/val_0121.png
# /content/working/working/synthdata/images/val/val_0140.png
# /content/working/working/synthdata/images/val/val_0126.png
# /content/working/working/synthdata/images/val/val_0060.png
# /content/working/working/synthdata/images/val/val_0680.png
# /content/working/working/synthdata/images/val/val_0123.png
# /content/working/working/synthdata/images/val/val_0856.png
# /content/working/working/synthdata/images/val/val_0542.png
# /content/working/working/synthdata/images/val/val_0200.png
# /content/working/working/synthdata/images/val/val_0831.png
# /content/working/working/synthdata/images/val/val_0683.png
# /content/working/working/synthdata/images/val/val_0137.png
# /content/working/working/synthdata/images/val/val_0687.png
# /content/working/working/synthdata/images/val/val_0771.png
# /content/working/working/synthdata/images/val/val_0061.png
# /content/working/working/synthdata/images/val/val_0143.png
# /content/working/working/synthdata/images/val/val_0550.png
# /content/working/working/synthdata/images/val/val_0247.png
# /content/working/working/synthdata/images/val/val_0179.png
# /content/working/working/synthdata/images/val/val_0345.png
# /content/working/working/synthdata/images/val/val_0740.png
# /content/working/working/synthdata/images/val/val_0849.png
# /content/working/working/synthdata/images/val/val_0305.png
# /content/working/working/synthdata/images/val/val_0845.png
# /content/working/working/synthdata/images/val/val_0462.png
# /content/working/working/synthdata/images/val/val_0444.png
# /content/working/working/synthdata/images/val/val_0189.png
# /content/working/working/synthdata/images/val/val_0106.png
# /content/working/working/synthdata/images/val/val_0386.png
# /content/working/working/synthdata/images/val/val_0082.png
# /content/working/working/synthdata/images/val/val_0755.png
# /content/working/working/synthdata/images/val/val_0264.png
# /content/working/working/synthdata/images/val/val_0406.png
# /content/working/working/synthdata/images/val/val_0452.png
# /content/working/working/synthdata/images/val/val_0029.png
# /content/working/working/synthdata/images/val/val_0853.png
# /content/working/working/synthdata/images/val/val_0458.png
# /content/working/working/synthdata/images/val/val_0777.png
# /content/working/working/synthdata/images/val/val_0585.png
# /content/working/working/synthdata/images/val/val_0009.png
# /content/working/working/synthdata/images/val/val_0847.png
# /content/working/working/synthdata/images/val/val_0769.png
# /content/working/working/synthdata/images/val/val_0222.png
# /content/working/working/synthdata/images/val/val_0581.png
# /content/working/working/synthdata/images/val/val_0797.png
# /content/working/working/synthdata/images/val/val_0691.png
# /content/working/working/synthdata/images/val/val_0088.png
# /content/working/working/synthdata/images/val/val_0130.png
# /content/working/working/synthdata/images/val/val_0107.png
# /content/working/working/synthdata/images/val/val_0697.png
# /content/working/working/synthdata/images/val/val_0597.png
# /content/working/working/synthdata/images/val/val_0864.png
# /content/working/working/synthdata/images/val/val_0617.png
# /content/working/working/synthdata/images/val/val_0694.png
# /content/working/working/synthdata/images/val/val_0136.png
# /content/working/working/synthdata/images/val/val_0094.png
# /content/working/working/synthdata/images/val/val_0070.png
# /content/working/working/synthdata/images/val/val_0081.png
# /content/working/working/synthdata/images/val/val_0572.png
# /content/working/working/synthdata/images/val/val_0852.png
# /content/working/working/synthdata/images/val/val_0194.png
# /content/working/working/synthdata/images/val/val_0382.png
# /content/working/working/synthdata/images/val/val_0510.png
# /content/working/working/synthdata/images/val/val_0201.png
# /content/working/working/synthdata/images/val/val_0235.png
# /content/working/working/synthdata/images/val/val_0057.png
# /content/working/working/synthdata/images/val/val_0320.png
# /content/working/working/synthdata/images/val/val_0556.png
# /content/working/working/synthdata/images/val/val_0427.png
# /content/working/working/synthdata/images/val/val_0230.png
# /content/working/working/synthdata/images/val/val_0733.png
# /content/working/working/synthdata/images/val/val_0737.png
# /content/working/working/synthdata/images/val/val_0445.png
# /content/working/working/synthdata/images/val/val_0839.png
# /content/working/working/synthdata/images/val/val_0506.png
# /content/working/working/synthdata/images/val/val_0776.png
# /content/working/working/synthdata/images/val/val_0258.png
# /content/working/working/synthdata/images/val/val_0654.png
# /content/working/working/synthdata/images/val/val_0642.png
# /content/working/working/synthdata/images/val/val_0809.png
# /content/working/working/synthdata/images/val/val_0455.png
# /content/working/working/synthdata/images/val/val_0236.png
# /content/working/working/synthdata/images/val/val_0328.png
# /content/working/working/synthdata/images/val/val_0266.png
# /content/working/working/synthdata/images/val/val_0649.png
# /content/working/working/synthdata/images/val/val_0440.png
# /content/working/working/synthdata/images/val/val_0765.png
# /content/working/working/synthdata/images/val/val_0342.png
# /content/working/working/synthdata/images/val/val_0156.png
# /content/working/working/synthdata/images/val/val_0329.png
# /content/working/working/synthdata/images/val/val_0062.png
# /content/working/working/synthdata/images/val/val_0498.png
# /content/working/working/synthdata/images/val/val_0656.png
# /content/working/working/synthdata/images/val/val_0128.png
# /content/working/working/synthdata/images/val/val_0448.png
# /content/working/working/synthdata/images/val/val_0489.png
# /content/working/working/synthdata/images/val/val_0287.png
# /content/working/working/synthdata/images/val/val_0675.png
# /content/working/working/synthdata/images/val/val_0271.png
# /content/working/working/synthdata/images/val/val_0582.png
# /content/working/working/synthdata/images/val/val_0001.png
# /content/working/working/synthdata/images/val/val_0711.png
# /content/working/working/synthdata/images/val/val_0098.png
# /content/working/working/synthdata/images/val/val_0215.png
# /content/working/working/synthdata/images/val/val_0394.png
# /content/working/working/synthdata/images/val/val_0223.png
# /content/working/working/synthdata/images/val/val_0068.png
# /content/working/working/synthdata/images/val/val_0674.png
# /content/working/working/synthdata/images/val/val_0413.png
# /content/working/working/synthdata/images/val/val_0690.png
# /content/working/working/synthdata/images/val/val_0592.png
# /content/working/working/synthdata/images/val/val_0723.png
# /content/working/working/synthdata/images/val/val_0787.png
# /content/working/working/synthdata/images/val/val_0609.png
# /content/working/working/synthdata/images/val/val_0817.png
# /content/working/working/synthdata/images/val/val_0485.png
# /content/working/working/synthdata/images/val/val_0788.png
# /content/working/working/synthdata/images/val/val_0102.png
# /content/working/working/synthdata/images/val/val_0330.png
# /content/working/working/synthdata/images/val/val_0799.png
# /content/working/working/synthdata/images/val/val_0325.png
# /content/working/working/synthdata/images/val/val_0759.png
# /content/working/working/synthdata/images/val/val_0533.png
# /content/working/working/synthdata/images/val/val_0676.png
# /content/working/working/synthdata/images/val/val_0461.png
# /content/working/working/synthdata/images/val/val_0064.png
# /content/working/working/synthdata/images/val/val_0795.png
# /content/working/working/synthdata/images/val/val_0549.png
# /content/working/working/synthdata/images/val/val_0127.png
# /content/working/working/synthdata/images/val/val_0237.png
# /content/working/working/synthdata/images/val/val_0341.png
# /content/working/working/synthdata/images/val/val_0590.png
# /content/working/working/synthdata/images/val/val_0365.png
# /content/working/working/synthdata/images/val/val_0543.png
# /content/working/working/synthdata/images/val/val_0051.png
# /content/working/working/synthdata/images/val/val_0854.png
# /content/working/working/synthdata/images/val/val_0294.png
# /content/working/working/synthdata/images/val/val_0418.png
# /content/working/working/synthdata/images/val/val_0596.png
# /content/working/working/synthdata/images/val/val_0428.png
# /content/working/working/synthdata/images/val/val_0144.png
# /content/working/working/synthdata/images/val/val_0681.png
# /content/working/working/synthdata/images/val/val_0435.png
# /content/working/working/synthdata/images/val/val_0089.png
# /content/working/working/synthdata/images/val/val_0007.png
# /content/working/working/synthdata/images/val/val_0437.png
# /content/working/working/synthdata/images/val/val_0348.png
# /content/working/working/synthdata/images/val/val_0490.png
# /content/working/working/synthdata/images/val/val_0726.png
# /content/working/working/synthdata/images/val/val_0310.png
# /content/working/working/synthdata/images/val/val_0523.png
# /content/working/working/synthdata/images/val/val_0578.png
# /content/working/working/synthdata/images/val/val_0677.png
# /content/working/working/synthdata/images/val/val_0159.png
# /content/working/working/synthdata/images/val/val_0688.png
# /content/working/working/synthdata/images/val/val_0608.png
# /content/working/working/synthdata/images/val/val_0480.png
# /content/working/working/synthdata/images/val/val_0019.png
# /content/working/working/synthdata/images/val/val_0160.png
# /content/working/working/synthdata/images/val/val_0607.png
# /content/working/working/synthdata/images/val/val_0805.png
# /content/working/working/synthdata/images/val/val_0366.png
# /content/working/working/synthdata/images/val/val_0491.png
# /content/working/working/synthdata/images/val/val_0092.png
# /content/working/working/synthdata/images/val/val_0026.png
# /content/working/working/synthdata/images/val/val_0505.png
# /content/working/working/synthdata/images/val/val_0541.png
# /content/working/working/synthdata/images/val/val_0595.png
# /content/working/working/synthdata/images/val/val_0099.png
# /content/working/working/synthdata/images/val/val_0025.png
# /content/working/working/synthdata/images/val/val_0846.png
# /content/working/working/synthdata/images/val/val_0497.png
# /content/working/working/synthdata/images/val/val_0331.png
# /content/working/working/synthdata/images/val/val_0244.png
# /content/working/working/synthdata/images/val/val_0219.png
# /content/working/working/synthdata/images/val/val_0041.png
# /content/working/working/synthdata/images/val/val_0504.png
# /content/working/working/synthdata/images/val/val_0719.png
# /content/working/working/synthdata/images/val/val_0145.png
# /content/working/working/synthdata/images/val/val_0333.png
# /content/working/working/synthdata/images/val/val_0741.png
# /content/working/working/synthdata/images/val/val_0728.png
# /content/working/working/synthdata/images/val/val_0073.png
# /content/working/working/synthdata/images/val/val_0154.png
# /content/working/working/synthdata/images/val/val_0193.png
# /content/working/working/synthdata/images/val/val_0838.png
# /content/working/working/synthdata/images/val/val_0738.png
# /content/working/working/synthdata/images/val/val_0376.png
# /content/working/working/synthdata/images/val/val_0011.png
# /content/working/working/synthdata/images/val/val_0049.png
# /content/working/working/synthdata/images/val/val_0747.png
# /content/working/working/synthdata/images/val/val_0422.png
# /content/working/working/synthdata/images/val/val_0069.png
# /content/working/working/synthdata/images/val/val_0354.png
# /content/working/working/synthdata/images/val/val_0705.png
# /content/working/working/synthdata/images/val/val_0407.png
# /content/working/working/synthdata/images/val/val_0010.png
# /content/working/working/synthdata/images/val/val_0717.png
# /content/working/working/synthdata/images/val/val_0263.png
# /content/working/working/synthdata/images/val/val_0304.png
# /content/working/working/synthdata/images/val/val_0289.png
# /content/working/working/synthdata/images/val/val_0575.png
# /content/working/working/synthdata/images/val/val_0384.png
# /content/working/working/synthdata/images/val/val_0766.png
# /content/working/working/synthdata/images/val/val_0633.png
# /content/working/working/synthdata/images/val/val_0040.png
# /content/working/working/synthdata/images/val/val_0113.png
# /content/working/working/synthdata/images/val/val_0014.png
# /content/working/working/synthdata/images/val/val_0432.png
# /content/working/working/synthdata/images/val/val_0103.png
# /content/working/working/synthdata/images/val/val_0214.png
# /content/working/working/synthdata/images/val/val_0419.png
# /content/working/working/synthdata/images/val/val_0808.png
# /content/working/working/synthdata/images/val/val_0714.png
# /content/working/working/synthdata/images/val/val_0790.png
# /content/working/working/synthdata/images/val/val_0650.png
# /content/working/working/synthdata/images/val/val_0067.png
# /content/working/working/synthdata/images/val/val_0710.png
# /content/working/working/synthdata/images/val/val_0208.png
# /content/working/working/synthdata/images/val/val_0411.png
# /content/working/working/synthdata/images/val/val_0216.png
# /content/working/working/synthdata/images/val/val_0768.png
# /content/working/working/synthdata/images/val/val_0261.png
# /content/working/working/synthdata/images/val/val_0637.png
# /content/working/working/synthdata/images/val/val_0837.png
# /content/working/working/synthdata/images/val/val_0539.png
# /content/working/working/synthdata/images/val/val_0370.png
# /content/working/working/synthdata/images/val/val_0385.png
# /content/working/working/synthdata/images/val/val_0499.png
# /content/working/working/synthdata/images/val/val_0832.png
# /content/working/working/synthdata/images/val/val_0176.png
# /content/working/working/synthdata/images/val/val_0631.png
# /content/working/working/synthdata/images/val/val_0151.png
# /content/working/working/synthdata/images/val/val_0811.png
# /content/working/working/synthdata/images/val/val_0860.png
# /content/working/working/synthdata/images/val/val_0566.png
# /content/working/working/synthdata/images/val/val_0669.png
# /content/working/working/synthdata/images/val/val_0814.png
# /content/working/working/synthdata/images/val/val_0789.png
# /content/working/working/synthdata/images/val/val_0530.png
# /content/working/working/synthdata/images/val/val_0848.png
# /content/working/working/synthdata/images/val/val_0827.png
# /content/working/working/synthdata/images/val/val_0610.png
# /content/working/working/synthdata/images/val/val_0792.png
# /content/working/working/synthdata/images/val/val_0661.png
# /content/working/working/synthdata/images/val/val_0615.png
# /content/working/working/synthdata/images/val/val_0470.png
# /content/working/working/synthdata/images/val/val_0393.png
# /content/working/working/synthdata/images/val/val_0017.png
# /content/working/working/synthdata/images/val/val_0410.png
# /content/working/working/synthdata/images/val/val_0417.png
# /content/working/working/synthdata/images/val/val_0586.png
# /content/working/working/synthdata/images/val/val_0012.png
# /content/working/working/synthdata/images/val/val_0371.png
# /content/working/working/synthdata/images/val/val_0436.png
# /content/working/working/synthdata/images/val/val_0296.png
# /content/working/working/synthdata/images/val/val_0826.png
# /content/working/working/synthdata/images/val/val_0830.png
# /content/working/working/synthdata/images/val/val_0508.png
# /content/working/working/synthdata/images/val/val_0405.png
# /content/working/working/synthdata/images/val/val_0820.png
# /content/working/working/synthdata/images/val/val_0855.png
# /content/working/working/synthdata/images/val/val_0306.png
# /content/working/working/synthdata/images/val/val_0234.png
# /content/working/working/synthdata/images/val/val_0577.png
# /content/working/working/synthdata/images/val/val_0000.png
# /content/working/working/synthdata/images/val/val_0851.png
# /content/working/working/synthdata/images/val/val_0467.png
# /content/working/working/synthdata/images/val/val_0420.png
# /content/working/working/synthdata/images/val/val_0501.png
# /content/working/working/synthdata/images/val/val_0104.png
# /content/working/working/synthdata/images/val/val_0093.png
# /content/working/working/synthdata/images/val/val_0168.png
# /content/working/working/synthdata/images/val/val_0618.png
# /content/working/working/synthdata/images/val/val_0568.png
# /content/working/working/synthdata/images/val/val_0037.png
# /content/working/working/synthdata/images/val/val_0257.png
# /content/working/working/synthdata/images/val/val_0085.png
# /content/working/working/synthdata/images/val/val_0182.png
# /content/working/working/synthdata/images/val/val_0362.png
# /content/working/working/synthdata/images/val/val_0397.png
# /content/working/working/synthdata/images/val/val_0262.png
# /content/working/working/synthdata/images/val/val_0402.png
# /content/working/working/synthdata/images/val/val_0573.png
# /content/working/working/synthdata/images/val/val_0528.png
# /content/working/working/synthdata/images/val/val_0224.png
# /content/working/working/synthdata/images/val/val_0372.png
# /content/working/working/synthdata/images/val/val_0835.png
# /content/working/working/synthdata/images/val/val_0022.png
# /content/working/working/synthdata/images/val/val_0821.png
# /content/working/working/synthdata/images/val/val_0716.png
# /content/working/working/synthdata/images/val/val_0246.png
# /content/working/working/synthdata/images/val/val_0270.png
# /content/working/working/synthdata/images/val/val_0859.png
# /content/working/working/synthdata/images/val/val_0359.png
# /content/working/working/synthdata/images/val/val_0375.png
# /content/working/working/synthdata/images/val/val_0693.png
# /content/working/working/synthdata/images/val/val_0670.png
# /content/working/working/synthdata/images/val/val_0343.png
# /content/working/working/synthdata/images/val/val_0640.png
# /content/working/working/synthdata/images/val/val_0232.png
# /content/working/working/synthdata/images/val/val_0265.png
# /content/working/working/synthdata/images/val/val_0824.png
# /content/working/working/synthdata/images/val/val_0794.png
# /content/working/working/synthdata/images/val/val_0756.png
# /content/working/working/synthdata/images/val/val_0090.png
# /content/working/working/synthdata/images/val/val_0752.png
# /content/working/working/synthdata/images/val/val_0648.png
# /content/working/working/synthdata/images/val/val_0227.png
# /content/working/working/synthdata/images/val/val_0084.png
# /content/working/working/synthdata/images/val/val_0131.png
# /content/working/working/synthdata/images/val/val_0538.png
# /content/working/working/synthdata/images/val/val_0421.png
# /content/working/working/synthdata/images/val/val_0664.png
# /content/working/working/synthdata/images/val/val_0245.png
# /content/working/working/synthdata/images/val/val_0753.png
# /content/working/working/synthdata/images/val/val_0843.png
# /content/working/working/synthdata/images/val/val_0569.png
# /content/working/working/synthdata/images/val/val_0278.png
# /content/working/working/synthdata/images/val/val_0389.png
# /content/working/working/synthdata/images/val/val_0078.png
# /content/working/working/synthdata/images/val/val_0111.png
# /content/working/working/synthdata/images/val/val_0074.png
# /content/working/working/synthdata/images/val/val_0651.png
# /content/working/working/synthdata/images/val/val_0557.png
# /content/working/working/synthdata/images/val/val_0702.png
# /content/working/working/synthdata/images/val/val_0110.png
# /content/working/working/synthdata/images/val/val_0347.png
# /content/working/working/synthdata/images/val/val_0280.png
# /content/working/working/synthdata/images/val/val_0241.png
# /content/working/working/synthdata/images/val/val_0626.png
# /content/working/working/synthdata/images/val/val_0481.png
# /content/working/working/synthdata/images/val/val_0044.png
# /content/working/working/synthdata/images/val/val_0095.png
# /content/working/working/synthdata/images/val/val_0132.png
# /content/working/working/synthdata/images/val/val_0274.png
# /content/working/working/synthdata/images/val/val_0429.png
# /content/working/working/synthdata/images/val/val_0186.png
# /content/working/working/synthdata/images/val/val_0027.png
# /content/working/working/synthdata/images/val/val_0169.png
# /content/working/working/synthdata/images/val/val_0748.png
# /content/working/working/synthdata/images/val/val_0065.png
# /content/working/working/synthdata/images/val/val_0678.png
# /content/working/working/synthdata/images/val/val_0657.png
# /content/working/working/synthdata/images/val/val_0767.png
# /content/working/working/synthdata/images/val/val_0564.png
# /content/working/working/synthdata/images/val/val_0643.png
# /content/working/working/synthdata/images/val/val_0514.png
# /content/working/working/synthdata/images/val/val_0401.png
# /content/working/working/synthdata/images/val/val_0532.png
# /content/working/working/synthdata/images/val/val_0013.png
# /content/working/working/synthdata/images/val/val_0447.png
# /content/working/working/synthdata/images/val/val_0834.png
# /content/working/working/synthdata/images/val/val_0339.png
# /content/working/working/synthdata/images/val/val_0605.png
# /content/working/working/synthdata/images/val/val_0671.png
# /content/working/working/synthdata/images/val/val_0801.png
# /content/working/working/synthdata/images/val/val_0603.png
# /content/working/working/synthdata/images/val/val_0449.png
# /content/working/working/synthdata/images/val/val_0613.png
# /content/working/working/synthdata/images/val/val_0043.png
# /content/working/working/synthdata/images/val/val_0732.png
# /content/working/working/synthdata/images/val/val_0058.png
# /content/working/working/synthdata/images/val/val_0392.png
# /content/working/working/synthdata/images/val/val_0059.png
# /content/working/working/synthdata/images/val/val_0584.png
# /content/working/working/synthdata/images/val/val_0283.png
# /content/working/working/synthdata/images/val/val_0031.png
# /content/working/working/synthdata/images/val/val_0337.png
# /content/working/working/synthdata/images/val/val_0439.png
# /content/working/working/synthdata/images/val/val_0433.png
# /content/working/working/synthdata/images/val/val_0399.png
# /content/working/working/synthdata/images/val/val_0639.png
# /content/working/working/synthdata/images/val/val_0277.png
# /content/working/working/synthdata/images/val/val_0686.png
# /content/working/working/synthdata/images/val/val_0238.png
# /content/working/working/synthdata/images/val/val_0211.png
# /content/working/working/synthdata/images/val/val_0327.png
# /content/working/working/synthdata/images/val/val_0196.png
# /content/working/working/synthdata/images/val/val_0124.png
# /content/working/working/synthdata/images/val/val_0120.png
# /content/working/working/synthdata/images/val/val_0243.png
# /content/working/working/synthdata/images/val/val_0108.png
# /content/working/working/synthdata/images/val/val_0828.png
# /content/working/working/synthdata/images/val/val_0627.png
# /content/working/working/synthdata/images/val/val_0638.png
# /content/working/working/synthdata/images/val/val_0784.png
# /content/working/working/synthdata/images/val/val_0488.png
# /content/working/working/synthdata/images/val/val_0181.png
# /content/working/working/synthdata/images/val/val_0560.png
# /content/working/working/synthdata/images/val/val_0023.png
# /content/working/working/synthdata/images/val/val_0456.png
# /content/working/working/synthdata/images/val/val_0173.png
# /content/working/working/synthdata/images/val/val_0125.png
# /content/working/working/synthdata/images/val/val_0479.png
# /content/working/working/synthdata/images/val/val_0684.png
# /content/working/working/synthdata/images/val/val_0292.png
# /content/working/working/synthdata/images/val/val_0522.png
# /content/working/working/synthdata/images/val/val_0486.png
# /content/working/working/synthdata/images/val/val_0404.png
# /content/working/working/synthdata/images/val/val_0356.png
# /content/working/working/synthdata/images/val/val_0163.png
# /content/working/working/synthdata/images/val/val_0047.png
# /content/working/working/synthdata/images/val/val_0804.png
# /content/working/working/synthdata/images/val/val_0105.png
# /content/working/working/synthdata/images/val/val_0460.png
# /content/working/working/synthdata/images/val/val_0502.png
# /content/working/working/synthdata/images/val/val_0537.png
# /content/working/working/synthdata/images/val/val_0507.png
# /content/working/working/synthdata/images/val/val_0276.png
# /content/working/working/synthdata/images/val/val_0398.png
# /content/working/working/synthdata/images/val/val_0157.png
# /content/working/working/synthdata/images/val/val_0474.png
# /content/working/working/synthdata/images/val/val_0152.png
# /content/working/working/synthdata/images/val/val_0758.png
# ...
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0969.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0727.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0229.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0798.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0500.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0931.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0825.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1532.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0673.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1515.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0047.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1455.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0714.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0503.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1294.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0109.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0398.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1397.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1827.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0323.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0884.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1754.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0380.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0873.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0909.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1720.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0809.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0328.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0354.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0443.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1143.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0092.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0084.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0599.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0165.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1485.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0880.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1666.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0291.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0760.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0810.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0158.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0075.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1841.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0401.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1322.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1574.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1157.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1362.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0187.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0510.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0633.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1460.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0302.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0788.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1577.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0013.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1831.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1029.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0780.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1851.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1640.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1624.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1740.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1065.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1452.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0745.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0334.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0273.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1439.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0952.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1169.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0415.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0485.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0425.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1601.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1218.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1424.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1828.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0535.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1753.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1356.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1025.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1080.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0533.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1503.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1604.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1262.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0369.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1120.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1649.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1012.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1492.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1137.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0434.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0218.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1150.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0539.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1182.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1105.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0828.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1703.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1309.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0489.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0438.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0583.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0242.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0142.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0289.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0141.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1498.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1038.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0036.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0115.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0283.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0207.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1024.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0691.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0729.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1031.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0497.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1132.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1094.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0688.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1625.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0829.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0217.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1705.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1545.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1000.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1860.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1023.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1249.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1730.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0087.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0724.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0876.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1672.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1095.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1234.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1263.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0365.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0128.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0465.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0679.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0226.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0976.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0572.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1412.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0532.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0807.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0051.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1550.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1704.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0783.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1351.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0156.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1284.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1785.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0936.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1293.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1168.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1317.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1667.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0118.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0040.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0801.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1702.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0808.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0755.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1804.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1714.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0763.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0010.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0315.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1104.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0671.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0110.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0864.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0053.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1631.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1734.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1343.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0674.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0189.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0838.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0804.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0973.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1221.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0286.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0502.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1832.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0224.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1712.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0794.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0574.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0409.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1826.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1400.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0590.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0988.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0710.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0454.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0802.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0201.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1664.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0835.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0264.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0127.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0134.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0357.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1568.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0282.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_0175.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1746.txt
# /content/working/__MACOSX/working/synthdata/labels/train/._train_1709.txt

# %%
# !pip install easyocr nltk jellyfish editdistance langdetect
# Out:
# Requirement already satisfied: easyocr in /usr/local/lib/python3.12/dist-packages (1.7.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: jellyfish in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.12/dist-packages (0.8.1)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.12/dist-packages (1.0.9)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from easyocr) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.5 in /usr/local/lib/python3.12/dist-packages (from easyocr) (0.23.0)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from easyocr) (4.12.0.88)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from easyocr) (1.16.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from easyocr) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from easyocr) (11.3.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from easyocr) (0.25.2)
# Requirement already satisfied: python-bidi in /usr/local/lib/python3.12/dist-packages (from easyocr) (0.6.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from easyocr) (6.0.2)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.12/dist-packages (from easyocr) (2.1.1)
# Requirement already satisfied: pyclipper in /usr/local/lib/python3.12/dist-packages (from easyocr) (1.3.0.post6)
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (from easyocr) (1.13.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from langdetect) (1.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (75.2.0)
# Collecting sympy>=1.13.3 (from torch->easyocr)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.4.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr) (2025.8.28)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr) (0.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->easyocr) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->easyocr) (3.0.2)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Installing collected packages: sympy
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.12
#     Uninstalling sympy-1.12:
#       Successfully uninstalled sympy-1.12
# Successfully installed sympy-1.14.0

# %%
import easyocr
import nltk
import editdistance
import jellyfish
import re
from nltk.corpus import wordnet as wn, brown, stopwords
from nltk import word_tokenize, pos_tag
from langdetect import detect, DetectorFactory

DetectorFactory.seed = 0

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('brown')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
freq_dist = nltk.FreqDist(w.lower() for w in brown.words())
stop_words = set(stopwords.words("english"))

# %%
def soundex_code(word):
    try:
        return jellyfish.soundex(word)
    except:
        return ""

visual_confusions = {
    "qing": ["ring", "ping", "king", "zing"],
    "rn": ["m"],
    "sceen": ["screen", "scene"],
    "barkinq": ["barking"],
    "gud": ["good"],
    "0": ["o"],
    "1": ["l", "i"],
    "5": ["s"],
    "8": ["b"],
    "@": ["a"],
    "$": ["s"]
}

phonetic_confusions = {
    "qing": ["ring", "ping", "king", "zing"],
    "gud": ["good"]
}

# %%
def generate_candidates(word):
    candidates = set()
    w = word.lower()

    # Visual confusions
    for key, vals in visual_confusions.items():
        if key in w:
            for val in vals:
                candidates.add(w.replace(key, val))

    # Phonetic similarity
    for ph_word, ph_vals in phonetic_confusions.items():
        if soundex_code(w) == soundex_code(ph_word):
            candidates.update(ph_vals)

    candidates.add(w)
    return list(candidates)

# %%
def best_candidate(word, candidates, context_words, window=3, index=0):
    best_word = word
    best_score = -1
    w = word.lower()

    context = context_words[max(0, index-window): index] + context_words[index+1: index+1+window]

    for cand in candidates:
        score = 0
        score += max(0, 5 - editdistance.eval(w, cand))
        score += 0.01 * freq_dist[cand]

        for ctx in context:
            if ctx.lower() not in stop_words:
                syns1 = wn.synsets(cand)
                syns2 = wn.synsets(ctx)
                sim = syns1[0].wup_similarity(syns2[0]) if syns1 and syns2 else 0
                score += sim * 10

        if score > best_score:
            best_score = score
            best_word = cand

    return best_word

# %%
def filter_english_words(tokens):
    """Return only tokens that are likely English words (letters only)"""
    return [t for t in tokens if re.fullmatch(r"[A-Za-z]+", t)]

# %%
def correct_sentence(sentence):
    words = word_tokenize(sentence)
    tagged = pos_tag(words)
    corrected = []

    # Filter only alphabetic words for correction
    for i, (word, tag) in enumerate(tagged):
        if re.fullmatch(r"[A-Za-z]+", word):
            candidates = generate_candidates(word)
            context = [w for j, (w, _) in enumerate(tagged) if j != i]
            best = best_candidate(word, candidates, context, index=i)
            corrected.append(best)
        else:
            corrected.append(word)

    return " ".join(corrected)

# %%
# Number of images to process (for testing)
N = 5

# Get all images in your folder
import os
image_folder = "/content/working/working/synthdata/images/train"
image_files = [os.path.join(image_folder, f) for f in os.listdir(image_folder)
               if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

# Limit to first N images
image_files = image_files[:N]

# Initialize EasyOCR reader
import easyocr
reader = easyocr.Reader(['en'])

ocr_sentences = []

# OCR with progress print
for idx, img_path in enumerate(image_files, 1):
    result = reader.readtext(img_path, detail=0)
    ocr_sentences.extend(result)
    print(f"OCR done: {idx}/{len(image_files)} images")

print(f"Total OCR-extracted lines: {len(ocr_sentences)}")
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# OCR done: 1/5 images
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# OCR done: 2/5 images
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# OCR done: 3/5 images
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# OCR done: 4/5 images
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# OCR done: 5/5 images
# Total OCR-extracted lines: 62

# %%
corrected_sentences = [correct_sentence(sent) for sent in ocr_sentences]

# Filter only English sentences
english_sentences = []
for sent in corrected_sentences:
    try:
        if detect(sent) == "en":
            english_sentences.append(sent)
    except:
        pass

print(f"Total corrected English sentences: {len(english_sentences)}")
# Out:
# Total corrected English sentences: 1

# %%
# Preview all corrected English sentences
if corrected_sentences:
    print("Corrected English outputs:\n")
    for i, sent in enumerate(corrected_sentences, 1):
        print(f"{i}. {sent}")
else:
    print("No meaningful English sentences were detected in OCR output.")
# Out:
# Corrected English outputs:
#
# 1. 6 1 b n
# 2. 9 p k
# 3. 3 p
# 4. e 9 9 b &
# 5. 3 f 97 l 7
# 6. 6 l
# 7. b 3 # k ( p 9 ^ p b e mkr a
# 8. 0 <
# 9. f 3p
# 10. m d
# 11. # j 4 ( €
# 12. 8 p w l
# 13. 0 `` xt h )
# 14. 0 m r € b 6 ]
# 15. n $ # d # n
# 16. 9 q
# 17. j r n 4 & ^ 5
# 18. p h j & n x
# 19. 0 b & > b > n
# 20. 1 ' u ] 4
# 21. la # [
# 22. l y fu
# 23. b < aa m <
# 24. p 0 &
# 25. ka / m6 2 /
# 26. 9 a ~
# 27. m n j l r e {
# 28. 0 f $ g
# 29. 1 6 / c
# 30. yn k
# 31. m # 9 ? /
# 32. 0 n 4 m $ a b
# 33. p j 0 0 n 1 r
# 34. ) _ 1 40 a t
# 35. 2
# 36. 2 &
# 37. 2 m j ml
# 38. 8 e € & k b
# 39. j # 8 7 &
# 40. 1 5 <
# 41. j 94 n 9 ~ 6
# 42. 1l # & > <
# 43. l ^ m k 0
# 44. m f 9 p
# 45. j ? n y
# 46. x m '41 <
# 47. 2 9 p ( <
# 48. mr $ & na ^
# 49. 94
# 50. 7 4 p ml a
# 51. cq / 0 € #
# 52. € 6 0
# 53. 9 # ni 3 k 0
# 54. ~198 j i
# 55. g }
# 56. b 6 & % l
# 57. 1 & md
# 58. 2 k q > 2 4
# 59. a k ) a 4 n 1 &
# 60. m a h a 9 l q
# 61. 8 > k # m
# 62. a e t
